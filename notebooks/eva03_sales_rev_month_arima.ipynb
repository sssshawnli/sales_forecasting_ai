# %%
import sys
import os

# 设置项目根目录为当前 notebook 所在路径的上一级目录
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    
from src.model import predict_rev_month_arima
from src.data_load import load_ordr,load_rdr1
from datetime import datetime
import pandas as pd

df_load_ordr = load_ordr()
df_load_rdr1 = load_rdr1()
df_merged = pd.merge(df_load_ordr,df_load_rdr1, on="DocEntry", how="inner")


predict_rev_month_arima(df_merged)
# Out:
# /home/shawn/pd_project/src/model.py:484: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train["rev_diff"] = df_train["rev"].diff()
# ADF test on revenue (before differencing):
# ADF Statistic: -6.469375306308117
# p-value: 1.3793581993462022e-08
# ADF test on differenced revenue:
# ADF Statistic: -8.50669634777325
# p-value: 1.1975494660223608e-13
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA model summary:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    rev   No. Observations:                   40
# Model:                 ARIMA(4, 1, 5)   Log Likelihood                -596.322
# Date:                Wed, 30 Jul 2025   AIC                           1212.644
# Time:                        14:42:40   BIC                           1229.279
# Sample:                    10-31-2020   HQIC                          1218.612
#                          - 01-31-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5083      0.082    -18.414      0.000      -1.669      -1.348
# ar.L2         -1.6110      0.058    -27.580      0.000      -1.725      -1.496
# ar.L3         -1.3805      0.075    -18.341      0.000      -1.528      -1.233
# ar.L4         -0.7995      0.061    -13.055      0.000      -0.920      -0.679
# ma.L1          0.8708     49.783      0.017      0.986     -96.701      98.443
# ma.L2          0.2584     53.888      0.005      0.996    -105.360     105.877
# ma.L3         -0.2674     53.660     -0.005      0.996    -105.440     104.905
# ma.L4         -0.8671     49.417     -0.018      0.986     -97.722      95.988
# ma.L5         -0.9947      0.114     -8.690      0.000      -1.219      -0.770
# sigma2      1.418e+11   2.51e-09   5.64e+19      0.000    1.42e+11    1.42e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.52   Jarque-Bera (JB):                 8.69
# Prob(Q):                              0.47   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.22   Skew:                             0.68
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.4e+37. Standard errors may be unstable.
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# SARIMAX with exogenous variables summary:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                  rev   No. Observations:                   40
# Model:             SARIMAX(4, 1, 5)x(1, 1, [1], 12)   Log Likelihood                -397.850
# Date:                              Wed, 30 Jul 2025   AIC                            825.700
# Time:                                      14:42:41   BIC                            845.137
# Sample:                                  10-31-2020   HQIC                           831.480
#                                        - 01-31-2024
# Covariance Type:                                opg
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# order_count  6425.4209   1502.364      4.277      0.000    3480.842    9370.000
# sku_count    3479.7468    828.347      4.201      0.000    1856.217    5103.277
# cust_count   2194.5496   1.11e+04      0.198      0.843   -1.96e+04     2.4e+04
# ar.L1          -0.2202      2.666     -0.083      0.934      -5.446       5.006
# ar.L2           0.4807      3.357      0.143      0.886      -6.099       7.061
# ar.L3           0.3169      1.994      0.159      0.874      -3.591       4.225
# ar.L4           0.4217      1.122      0.376      0.707      -1.778       2.622
# ma.L1          -0.2820      5.047     -0.056      0.955     -10.173       9.609
# ma.L2          -0.1507     27.942     -0.005      0.996     -54.916      54.615
# ma.L3          -0.2766     22.495     -0.012      0.990     -44.366      43.813
# ma.L4          -0.7864     26.210     -0.030      0.976     -52.156      50.584
# ma.L5           0.6062     18.150      0.033      0.973     -34.967      36.180
# ar.S.L12        0.4423      0.344      1.287      0.198      -0.231       1.116
# ma.S.L12       -0.9957     32.918     -0.030      0.976     -65.513      63.522
# sigma2       1.049e+11   7.46e-06   1.41e+16      0.000    1.05e+11    1.05e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.50   Jarque-Bera (JB):                 1.46
# Prob(Q):                              0.06   Prob(JB):                         0.48
# Heteroskedasticity (H):               1.61   Skew:                            -0.15
# Prob(H) (two-sided):                  0.49   Kurtosis:                         1.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.22e+34. Standard errors may be unstable.
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# SARIMA without exogenous variables summary:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                  rev   No. Observations:                   40
# Model:             SARIMAX(4, 1, 5)x(1, 1, [1], 12)   Log Likelihood                -464.220
# Date:                              Wed, 30 Jul 2025   AIC                            952.441
# Time:                                      14:42:43   BIC                            967.991
# Sample:                                  10-31-2020   HQIC                           957.065
#                                        - 01-31-2024
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.0672      0.038    -28.189      0.000      -1.141      -0.993
# ar.L2         -1.7583      0.032    -54.464      0.000      -1.822      -1.695
# ar.L3         -1.0517      0.035    -29.632      0.000      -1.121      -0.982
# ar.L4         -0.9873      0.035    -28.543      0.000      -1.055      -0.920
# ma.L1          0.8687      6.584      0.132      0.895     -12.035      13.772
# ma.L2          1.6064      8.764      0.183      0.855     -15.570      18.783
# ma.L3          0.7653      2.943      0.260      0.795      -5.004       6.534
# ma.L4          0.8733     10.262      0.085      0.932     -19.241      20.987
# ma.L5         -0.1091      1.191     -0.092      0.927      -2.443       2.225
# ar.S.L12      -0.0401      0.031     -1.276      0.202      -0.102       0.021
# ma.S.L12      -0.9998     10.921     -0.092      0.927     -22.404      20.404
# sigma2      7.297e+10   1.47e-10   4.96e+20      0.000     7.3e+10     7.3e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.99   Jarque-Bera (JB):                 1.91
# Prob(Q):                              0.05   Prob(JB):                         0.39
# Heteroskedasticity (H):               0.55   Skew:                            -0.04
# Prob(H) (two-sided):                  0.39   Kurtosis:                         1.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.28e+38. Standard errors may be unstable.
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/shawn/pd_project/venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
