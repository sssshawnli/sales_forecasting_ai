# %%
import sys
import os

# 设置项目根目录为当前 notebook 所在路径的上一级目录
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    
from src.model import predict_revenue,predict_revenue_sm,predict_revenue_lasso,predict_revenue_ridge
from src.evaluate import evaluate_sales_revenue_regression
from src.data_load import load_ordr

df = load_ordr()

print(predict_revenue(df))
#predict_revenue_sm(df)
#print(predict_revenue_lasso(df))

#print(predict_revenue_ridge(df))

evaluate_sales_revenue_regression(df)
# Out:
# R-squared: 0.7126
# Intercept: 4809307812.89
# Slope: -2349890.13
# p-value: 0.155838
#    Year           rev
# 0  2021 61,992,615.75
# 1  2022 55,239,100.27
# 2  2023 55,223,589.04
# 3  2024 54,164,819.07
# 4  2025 50,780,305.71
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.713
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     4.959
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):              0.156
# Time:                        14:56:09   Log-Likelihood:                -62.985
# No. Observations:                   4   AIC:                             130.0
# Df Residuals:                       2   BIC:                             128.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
